# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh4847/NLP/blob/main/stop_word_removal_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
text = """
Natural Language Processing is a field of artificial intelligence.
It helps computers understand and process human language.
"""

print("Original Text:")
print(text)
# Out:
# Original Text:
#
# Natural Language Processing is a field of artificial intelligence.
# It helps computers understand and process human language.

# %%
words = word_tokenize(text)

print("Tokens:")
print(words)
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', '.', 'It', 'helps', 'computers', 'understand', 'and', 'process', 'human', 'language', '.']

# %%
stop_words = set(stopwords.words('english'))

print("Some English Stop Words:")
print(list(stop_words)[:20])
# Out:
# Some English Stop Words:
# ["i've", "he'll", 'ma', 'couldn', 'a', "didn't", 'had', 'isn', 'and', "we'd", 'm', 'as', 'was', 'off', 'wasn', 'any', 'been', "we'll", "hadn't", 'll']

# %%
filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("After Stop Word Removal:")
print(filtered_words)
# Out:
# After Stop Word Removal:
# ['Natural', 'Language', 'Processing', 'field', 'artificial', 'intelligence', '.', 'helps', 'computers', 'understand', 'process', 'human', 'language', '.']

# %%
filtered_text = " ".join(filtered_words)

print("Final Text:")
print(filtered_text)
# Out:
# Final Text:
# Natural Language Processing field artificial intelligence . helps computers understand process human language .
