# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh4847/NLP/blob/main/NER_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 68.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
text = """
Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne.
The company is headquartered in Cupertino, California.
Apple released the iPhone in 2007.
"""

print("Original Text:")
print(text)
# Out:
# Original Text:
#
# Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne.
# The company is headquartered in Cupertino, California.
# Apple released the iPhone in 2007.

# %%
doc = nlp(text)

# %%
print("Named Entities:\n")

for entity in doc.ents:
    print(entity.text, "->", entity.label_)
# Out:
# Named Entities:
#
# Apple Inc. -> ORG
# Steve Jobs -> PERSON
# Steve Wozniak -> PERSON
# Ronald Wayne -> PERSON
# Cupertino -> GPE
# California -> GPE
# Apple -> ORG
# iPhone -> ORG
# 2007 -> DATE

# %%
print("Named Entities with Descriptions:\n")

for entity in doc.ents:
    print(
        entity.text,
        "->",
        entity.label_,
        "->",
        spacy.explain(entity.label_)
    )
# Out:
# Named Entities with Descriptions:
#
# Apple Inc. -> ORG -> Companies, agencies, institutions, etc.
# Steve Jobs -> PERSON -> People, including fictional
# Steve Wozniak -> PERSON -> People, including fictional
# Ronald Wayne -> PERSON -> People, including fictional
# Cupertino -> GPE -> Countries, cities, states
# California -> GPE -> Countries, cities, states
# Apple -> ORG -> Companies, agencies, institutions, etc.
# iPhone -> ORG -> Companies, agencies, institutions, etc.
# 2007 -> DATE -> Absolute or relative dates or periods

# %%
print("Entities with Character Positions:\n")

for entity in doc.ents:
    print(
        entity.text,
        "->",
        entity.label_,
        "-> Start:", entity.start_char,
        "End:", entity.end_char
    )
# Out:
# Entities with Character Positions:
#
# Apple Inc. -> ORG -> Start: 1 End: 11
# Steve Jobs -> PERSON -> Start: 27 End: 37
# Steve Wozniak -> PERSON -> Start: 39 End: 52
# Ronald Wayne -> PERSON -> Start: 58 End: 70
# Cupertino -> GPE -> Start: 104 End: 113
# California -> GPE -> Start: 115 End: 125
# Apple -> ORG -> Start: 127 End: 132
# iPhone -> ORG -> Start: 146 End: 152
# 2007 -> DATE -> Start: 156 End: 160

# %%
from spacy import displacy

displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Wozniak
# ...
