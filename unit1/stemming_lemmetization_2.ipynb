# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh4847/NLP/blob/main/stemming_lemmetization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
text = "The students are studying and playing games. They studied yesterday."

words = word_tokenize(text)

print("Original Words:")
print(words)
# Out:
# Original Words:
# ['The', 'students', 'are', 'studying', 'and', 'playing', 'games', '.', 'They', 'studied', 'yesterday', '.']

# %%
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in words]

print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['the', 'student', 'are', 'studi', 'and', 'play', 'game', '.', 'they', 'studi', 'yesterday', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['The', 'student', 'are', 'studying', 'and', 'playing', 'game', '.', 'They', 'studied', 'yesterday', '.']
