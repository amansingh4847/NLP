# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh4847/NLP/blob/main/unit2/n_gram_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sentence = "The quick brown fox jumps over the lazy dog."

print("Original Sentence:")
print(sentence)
# Out:
# Original Sentence:
# The quick brown fox jumps over the lazy dog.

# %%
tokens = word_tokenize(sentence)

print("Tokens:")
print(tokens)
# Out:
# Tokens:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.']

# %%
bigrams = list(ngrams(tokens, 2))

print("Bigrams:")
for bigram in bigrams:
    print(bigram)
# Out:
# Bigrams:
# ('The', 'quick')
# ('quick', 'brown')
# ('brown', 'fox')
# ('fox', 'jumps')
# ('jumps', 'over')
# ('over', 'the')
# ('the', 'lazy')
# ('lazy', 'dog')
# ('dog', '.')

# %%
trigrams = list(ngrams(tokens, 3))

print("Trigrams:")
for trigram in trigrams:
    print(trigram)
# Out:
# Trigrams:
# ('The', 'quick', 'brown')
# ('quick', 'brown', 'fox')
# ('brown', 'fox', 'jumps')
# ('fox', 'jumps', 'over')
# ('jumps', 'over', 'the')
# ('over', 'the', 'lazy')
# ('the', 'lazy', 'dog')
# ('lazy', 'dog', '.')

# %%
n = 4

n_grams = list(ngrams(tokens, n))

print(f"{n}-grams:")

for gram in n_grams:
    print(gram)
# Out:
# 4-grams:
# ('The', 'quick', 'brown', 'fox')
# ('quick', 'brown', 'fox', 'jumps')
# ('brown', 'fox', 'jumps', 'over')
# ('fox', 'jumps', 'over', 'the')
# ('jumps', 'over', 'the', 'lazy')
# ('over', 'the', 'lazy', 'dog')
# ('the', 'lazy', 'dog', '.')

# %%
words = [word for word in tokens if word.isalnum()]

print("Words without punctuation:")
print(words)

bigrams = list(ngrams(words, 2))
trigrams = list(ngrams(words, 3))

print("\nBigrams:")
for gram in bigrams:
    print(gram)

print("\nTrigrams:")
for gram in trigrams:
    print(gram)
# Out:
# Words without punctuation:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
# Bigrams:
# ('The', 'quick')
# ('quick', 'brown')
# ('brown', 'fox')
# ('fox', 'jumps')
# ('jumps', 'over')
# ('over', 'the')
# ('the', 'lazy')
# ('lazy', 'dog')
#
# Trigrams:
# ('The', 'quick', 'brown')
# ('quick', 'brown', 'fox')
# ('brown', 'fox', 'jumps')
# ('fox', 'jumps', 'over')
# ('jumps', 'over', 'the')
# ('over', 'the', 'lazy')
# ('the', 'lazy', 'dog')
